# %% [markdown]
# # Intro to MACE

# %% [markdown]
# In this tutorial, you will learn how to fit a Message Passing Neural Network called `MACE`, which is a highly accurate and efficient MLIP. If you would like to understand this method in more detail, you can find the [original method paper](https://proceedings.neurips.cc/paper_files/paper/2022/file/4a36c3c51af11ed9f34615b81edb5bbc-Paper-Conference.pdf). MACE was developed by unifying the Atomic Cluster Expansion (ACE) approach with the Neural Equivariant Interatomic Potentials (NequIP). The mathematical formalism which unifies these methods is explained in the [accompaning paper](https://doi.org/10.48550/arXiv.2205.06643). Another [useful reference](https://doi.org/10.48550/arXiv.2305.14247) showcases the methods performance on published benchmark datasets. The [code implementation](https://github.com/ACEsuit/mace) is publically available and [here](https://mace-docs.readthedocs.io/en/latest/) you can find the accompaning documentation.
#
# We will start by creating a simple potential on the same reference data from yesterday and reproduce the tests we used for GAP. We will then go beyond testing on fixed data and explore the stability of the potential in Molecular Dynamics (MD) simulations. We will test ideas of`iterative training` to improve the potential and `active learning` to automate the training process.
#
# This notebook copy is "read only", so you will need to duplicate the project in your own workspace in order to modify and run the notebook. Click on the settings button and duplicate. Make sure your "Environment" is set to "Python 3.10". The "Init" notebook will run automatically when you start and it will install all the prerequisite libraries for this tutorial (in about 2 mins).
#
# If the notebook stops responding (e.g. figures don't appear, the MACE fitting process stops or runs out of memmory), just restart the virtual machine in the "Environment" tab from the left menu.

# %% [markdown]
# # Fitting a Simple MACE Model

# %% [markdown]
# We will start by splitting the data into train and test sets the same as we did for GAP. In practice MACE extrapolates better than GAP, so we can get away with less data.

# %%
from ase.io import read, write

db = read('data/solvent_xtb.xyz', ':')

#non-periodic data is handled correctly by MACE, so we do not need to change anything
write('data/solvent_mace_train.xyz', db[:203])
write('data/solvent_mace_test.xyz', db[203:403])
# Out:
# /root/venv/lib/python3.10/site-packages/ase/io/extxyz.py:1000: UserWarning: write_xyz() overwriting array "forces" present in atoms.arrays with stored results from calculator
#   warnings.warn('write_xyz() overwriting array "{0}" present '

# %% [markdown]
# #### Training files
#
# To train a MACE model, you will use the `run_train.py`command which takes the following arguments:
#
# First specify the name of your model and final log file using the `--name` flag.
#
# You can specify the training file with the `--train_file` flag. The validation set can either be specified as a separate file using the `--valid_file` keyword, or it can be specified as a fraction of the training set using the `--valid_fraction` keyword. The validation set is not used for optimizing the model but to estimate the model accuracy during training.
#
# It is also possible to provide a test set using the `--test_file` keyword. This set is entirely independent and only gets evaluated at the end of the training process.
#
# __________________
#
# #### Reference energies
#
# It is usually preferred to add the isolated atoms to the training set, rather than reading in their energies through the command line. MACE will automatically identify these atoms in the training set if they are labels correctly with `config_type=IsolatedAtom` in their `info` fields (we have done this yesterday when preparing the data). If you prefer not to use or do not know the energies of the isolated atoms, you can use the option `--E0s="average"` which estimates the atomic energies by least squares regression.
#
# __________________
#
#
# #### Model
#
# ##### The Messages
#
# To control the model size, you need to change `--hidden_irreps`. For most applications, the recommended default model size is `--hidden_irreps='256x0e'` (meaning 256 invariant messages) or `--hidden_irreps='128x0e + 128x1o'` (meaning 128 equivariant messages). If the model is not accurate enough, you can include higher order features, e.g., `128x0e + 128x1o + 128x2e`, or increase the number of channels to `256`. The number of message passing layers can be controled via the `--num_ineractions` parameter. **Increasing the model size and the number of layers will lead to more accurate but slower models.**
#
# ##### Correlation order
#
# MACE uses a body order expansion on the site energy:
#
# $$
# E_{i} = E^{(0)}_{i} + \sum_{j} E_{ij}^{(1)} + \sum_{jk} E_{ijk}^{(2)} + ...
# $$
#
# The correlation order corresponds to the order that MACE induces at each layer. Choosing `--correlation=3` will create basis function of up to 4-body (ijke) indices, for each layer. Because of the multiple layers of MACE, the total correlation order is much higher. A two layers mace, with `--correlation=3` has a total body order of 13.
#
# ##### Angular resolution
#
# The angular resolution describes how precise the model can identify angles. This is controled by `l_max`. The higher this integer, more precise is the angular resolution. Larger value will result in more accurate but slower models. The default is `l_max=3`.
#
# ##### Cutoff radius
#
# The cutoff radius controls the locality of the model. A `--r_max=3.0` means that the model assumes atoms seperated by a distance of more than 3.0 A do not directly `communicate`. Because the model has two layers, atoms further than 3.0 A can still `communicate` by proxy. The actual receptive field of the model is the number of layers times the cutoff distance.
#
# __________________
#
#
# #### Data keys
#
# When parsing the data files the energies are read using the keyword `energy` and the forces using the keyword `forces`. To change that, specify the `--energy_key` and `--forces_key`.
#
# __________________
#
#
# #### Checkpoints
#
# Fitting this model will take about `12 mins`. You can continue the fitting from the last checkpoint by using the flag `--restart_latest`. The checkpoint saves the best model that currently has been trained. All checkpoints are saved in ./checkpoints folder. We can also continue from a restart when extending the dataset.
#
# __________________
#
#
# #### Training parameters
#
# These parameters are related to the training protocols: `--batch_size` represents the number of configs used to compute the gradients for each full update of all network parameters (stocastic gradient descent). The first `epoch` is completed when all the training data has been employed once in updating the weights and `--epochs` represents the number of such epochs. During training you will notice energy errors are at first much higher than force errors, MACE implements a special protocol that increases the weight on the energy in the loss function (`--swa_energy_weight`) once the forces are sufficiently accurate. The starting epoch for this special protocol can be controled by chaning `--start_swa`.
#
# #### Validation parameters
#
# The validation set controls the stopping of the training. At each `--eval_interval` the model is tested on the validation set. We also evaluate the set by batch size, controlled by `--valid_batch_size`. If the accuracy of the model stops improving on the validation set for `--patience` number of epochs. This is called **early stopping**.

# %%
# !python3 ./mace/scripts/run_train.py \
    --name="model" \
    --train_file="data/solvent_mace_train.xyz" \
    --valid_fraction=0.05 \
    --test_file="maceTests/solvent_test.xyz" \
    --E0s="isolated" \
    --energy_key="energy" \
    --forces_key="forces" \
    --model="MACE" \
    --num_interactions=2 \
    --max_ell=2 \
    --hidden_irreps="16x0e" \
    --num_cutoff_basis=5 \
    --correlation=2 \
    --r_max=3.0 \
    --batch_size=5 \
    --valid_batch_size=5 \
    --eval_interval=1 \
    --max_num_epochs=30 \
    --start_swa=15 \
    --swa_energy_weight=1000 \
    --ema \
    --ema_decay=0.99 \
    --amsgrad \
    --error_table="PerAtomRMSE" \
    --default_dtype="float32" \
    --swa \
    --device=cpu \
    --seed=1234
# Out:
# 2023-07-26 15:38:45.793 INFO: MACE version: 0.2.0
# 2023-07-26 15:38:45.793 INFO: Configuration: Namespace(name='model', seed=1234, log_dir='logs', model_dir='.', checkpoints_dir='checkpoints', results_dir='results', downloads_dir='downloads', device='cpu', default_dtype='float32', log_level='INFO', error_table='PerAtomRMSE', model='MACE', r_max=3.0, num_radial_basis=8, num_cutoff_basis=5, interaction='RealAgnosticResidualInteractionBlock', interaction_first='RealAgnosticResidualInteractionBlock', max_ell=2, correlation=2, num_interactions=2, MLP_irreps='16x0e', radial_MLP='[64, 64, 64]', hidden_irreps='16x0e', num_channels=None, max_L=None, gate='silu', scaling='rms_forces_scaling', avg_num_neighbors=1, compute_avg_num_neighbors=True, compute_stress=False, compute_forces=True, train_file='data/solvent_mace_train.xyz', valid_file=None, valid_fraction=0.05, test_file='maceTests/solvent_test.xyz', E0s='isolated', energy_key='energy', forces_key='forces', virials_key='virials', stress_key='stress', dipole_key='dipole', charges_key='charges', loss='weighted', forces_weight=100.0, swa_forces_weight=100.0, energy_weight=1.0, swa_energy_weight=1000.0, virials_weight=1.0, swa_virials_weight=10.0, stress_weight=1.0, swa_stress_weight=10.0, dipole_weight=1.0, swa_dipole_weight=1.0, config_type_weights='{"Default":1.0}', huber_delta=0.01, optimizer='adam', batch_size=5, valid_batch_size=5, lr=0.01, swa_lr=0.001, weight_decay=5e-07, amsgrad=True, scheduler='ReduceLROnPlateau', lr_factor=0.8, scheduler_patience=50, lr_scheduler_gamma=0.9993, swa=True, start_swa=15, ema=True, ema_decay=0.99, max_num_epochs=30, patience=2048, eval_interval=1, keep_checkpoints=False, restart_latest=False, save_cpu=False, clip_grad=10.0, wandb=False, wandb_project='', wandb_entity='', wandb_name='', wandb_log_hypers=['num_channels', 'max_L', 'correlation', 'lr', 'swa_lr', 'weight_decay', 'batch_size', 'max_num_epochs', 'start_swa', 'energy_weight', 'forces_weight'])
# 2023-07-26 15:38:45.793 INFO: Using CPU
# 2023-07-26 15:38:45.988 INFO: Using isolated atom energies from training file
# 2023-07-26 15:38:46.001 INFO: Loaded 200 training configurations from 'data/solvent_mace_train.xyz'
# 2023-07-26 15:38:46.002 INFO: Using random 5.0% of training set for validation
# 2023-07-26 15:38:46.176 INFO: Loaded 200 test configurations from 'maceTests/solvent_test.xyz'
# 2023-07-26 15:38:46.176 INFO: Total number of configurations: train=190, valid=10, tests=[Default: 200]
# 2023-07-26 15:38:46.189 INFO: AtomicNumberTable: (1, 6, 8)
# 2023-07-26 15:38:46.189 INFO: Atomic energies: [-10.707211383396714, -48.847445262804705, -102.57117256025786]
# 2023-07-26 15:38:46.844 INFO: WeightedEnergyForcesLoss(energy_weight=1.000, forces_weight=100.000)
# 2023-07-26 15:38:47.049 INFO: Average number of neighbors: 7.014963150024414
# 2023-07-26 15:38:47.049 INFO: Selected the following outputs: {'energy': True, 'forces': True, 'virials': False, 'stress': False, 'dipoles': False}
# 2023-07-26 15:38:47.049 INFO: Building model
# 2023-07-26 15:38:47.049 INFO: Hidden irreps: 16x0e
# 2023-07-26 15:38:49.131 INFO: Using stochastic weight averaging (after 15 epochs) with energy weight : 1000.0, forces weight : 100.0 and learning rate : 0.001
# 2023-07-26 15:38:49.266 INFO: ScaleShiftMACE(
#   (node_embedding): LinearNodeEmbeddingBlock(
#     (linear): Linear(3x0e -> 16x0e | 48 weights)
#   )
#   (radial_embedding): RadialEmbeddingBlock(
#     (bessel_fn): BesselBasis(r_max=3.0, num_basis=8, trainable=False)
#     (cutoff_fn): PolynomialCutoff(p=5.0, r_max=3.0)
#   )
#   (spherical_harmonics): SphericalHarmonics()
#   (atomic_energies_fn): AtomicEnergiesBlock(energies=[-10.7072, -48.8474, -102.5712])
#   (interactions): ModuleList(
#     (0): RealAgnosticInteractionBlock(
#       (linear_up): Linear(16x0e -> 16x0e | 256 weights)
#       (conv_tp): TensorProduct(16x0e x 1x0e+1x1o+1x2e -> 16x0e+16x1o+16x2e | 48 paths | 48 weights)
#       (conv_tp_weights): FullyConnectedNet[8, 64, 64, 64, 48]
#       (linear): Linear(16x0e+16x1o+16x2e -> 16x0e+16x1o+16x2e | 768 weights)
#       (skip_tp): FullyConnectedTensorProduct(16x0e+16x1o+16x2e x 3x0e -> 16x0e+16x1o+16x2e | 2304 paths | 2304 weights)
#       (reshape): reshape_irreps()
#     )
#     (1): RealAgnosticResidualInteractionBlock(
#       (linear_up): Linear(16x0e -> 16x0e | 256 weights)
#       (conv_tp): TensorProduct(16x0e x 1x0e+1x1o+1x2e -> 16x0e+16x1o+16x2e | 48 paths | 48 weights)
#       (conv_tp_weights): FullyConnectedNet[8, 64, 64, 64, 48]
#       (linear): Linear(16x0e+16x1o+16x2e -> 16x0e+16x1o+16x2e | 768 weights)
#       (skip_tp): FullyConnectedTensorProduct(16x0e x 3x0e -> 16x0e | 768 paths | 768 weights)
#       (reshape): reshape_irreps()
#     )
#   )
#   (products): ModuleList(
#     (0): EquivariantProductBasisBlock(
#       (symmetric_contractions): SymmetricContraction(
#         (contractions): ModuleList(
#           (0): Contraction(
#             (contractions_weighting): ModuleList(
#               (0): GraphModule()
#             )
#             (contractions_features): ModuleList(
#               (0): GraphModule()
#             )
#             (weights): ParameterList(  (0): Parameter containing: [torch.FloatTensor of size 3x1x16])
#             (graph_opt_main): GraphModule()
#           )
#         )
#       )
#       (linear): Linear(16x0e -> 16x0e | 256 weights)
#     )
#     (1): EquivariantProductBasisBlock(
#       (symmetric_contractions): SymmetricContraction(
#         (contractions): ModuleList(
#           (0): Contraction(
#             (contractions_weighting): ModuleList(
#               (0): GraphModule()
#             )
#             (contractions_features): ModuleList(
#               (0): GraphModule()
#             )
#             (weights): ParameterList(  (0): Parameter containing: [torch.FloatTensor of size 3x1x16])
#             (graph_opt_main): GraphModule()
#           )
#         )
#       )
#       (linear): Linear(16x0e -> 16x0e | 256 weights)
#     )
#   )
#   (readouts): ModuleList(
#     (0): LinearReadoutBlock(
#       (linear): Linear(16x0e -> 1x0e | 16 weights)
#     )
#     (1): NonLinearReadoutBlock(
#       (linear_1): Linear(16x0e -> 16x0e | 256 weights)
#       (non_linearity): Activation [x] (16x0e -> 16x0e)
#       (linear_2): Linear(16x0e -> 1x0e | 16 weights)
#     )
#   )
#   (scale_shift): ScaleShiftBlock(scale=2.262043, shift=0.000000)
# )
# 2023-07-26 15:38:49.269 INFO: Number of parameters: 29904
# 2023-07-26 15:38:49.269 INFO: Optimizer: Adam (
# Parameter Group 0
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: embedding
#     swa_lr: 0.001
#     weight_decay: 0.0
#
# Parameter Group 1
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: interactions_decay
#     swa_lr: 0.001
#     weight_decay: 5e-07
#
# Parameter Group 2
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: interactions_no_decay
#     swa_lr: 0.001
#     weight_decay: 0.0
#
# Parameter Group 3
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: products
#     swa_lr: 0.001
#     weight_decay: 5e-07
#
# Parameter Group 4
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: readouts
#     swa_lr: 0.001
#     weight_decay: 0.0
# )
# 2023-07-26 15:38:49.269 INFO: Using gradient clipping with tolerance=10.000
# 2023-07-26 15:38:49.270 INFO: Started training
# 2023-07-26 15:39:38.118 INFO: Epoch 0: loss=93.5908, RMSE_E_per_atom=5310.8 meV, RMSE_F=807.5 meV / A
# 2023-07-26 15:40:12.337 INFO: Epoch 1: loss=54.4642, RMSE_E_per_atom=5033.5 meV, RMSE_F=535.2 meV / A
# 2023-07-26 15:40:49.029 INFO: Epoch 2: loss=42.5010, RMSE_E_per_atom=4813.3 meV, RMSE_F=437.0 meV / A
# 2023-07-26 15:41:27.486 INFO: Epoch 3: loss=33.0261, RMSE_E_per_atom=4649.8 meV, RMSE_F=337.7 meV / A
# 2023-07-26 15:42:06.363 INFO: Epoch 4: loss=27.5193, RMSE_E_per_atom=4491.1 meV, RMSE_F=274.3 meV / A
# 2023-07-26 15:42:20.347 INFO: Epoch 5: loss=21.5238, RMSE_E_per_atom=4053.7 meV, RMSE_F=227.0 meV / A
# 2023-07-26 15:42:44.729 INFO: Epoch 6: loss=18.2783, RMSE_E_per_atom=3592.3 meV, RMSE_F=227.4 meV / A
# 2023-07-26 15:43:17.534 INFO: Epoch 7: loss=16.5022, RMSE_E_per_atom=3158.8 meV, RMSE_F=245.3 meV / A
# 2023-07-26 15:43:49.057 INFO: Epoch 8: loss=15.4405, RMSE_E_per_atom=2659.0 meV, RMSE_F=274.4 meV / A
# 2023-07-26 15:44:09.197 INFO: Epoch 9: loss=13.7112, RMSE_E_per_atom=2250.0 meV, RMSE_F=278.8 meV / A
# 2023-07-26 15:44:44.401 INFO: Epoch 10: loss=12.4107, RMSE_E_per_atom=1853.2 meV, RMSE_F=283.2 meV / A
# 2023-07-26 15:45:20.814 INFO: Epoch 11: loss=10.3429, RMSE_E_per_atom=1524.9 meV, RMSE_F=268.1 meV / A
# 2023-07-26 15:45:59.333 INFO: Epoch 12: loss=8.6227, RMSE_E_per_atom=1180.6 meV, RMSE_F=254.3 meV / A
# 2023-07-26 15:46:33.081 INFO: Epoch 13: loss=7.2622, RMSE_E_per_atom=917.1 meV, RMSE_F=239.8 meV / A
# 2023-07-26 15:47:07.146 INFO: Epoch 14: loss=6.3630, RMSE_E_per_atom=712.9 meV, RMSE_F=229.1 meV / A
# 2023-07-26 15:47:07.186 INFO: Changing loss based on SWA
# 2023-07-26 15:47:33.163 INFO: Epoch 15: loss=178.9109, RMSE_E_per_atom=415.5 meV, RMSE_F=237.1 meV / A
# 2023-07-26 15:48:06.298 INFO: Epoch 16: loss=66.1880, RMSE_E_per_atom=245.2 meV, RMSE_F=233.3 meV / A
# 2023-07-26 15:48:35.790 INFO: Epoch 17: loss=28.0907, RMSE_E_per_atom=149.2 meV, RMSE_F=228.9 meV / A
# 2023-07-26 15:49:01.279 INFO: Epoch 18: loss=14.2708, RMSE_E_per_atom=93.5 meV, RMSE_F=223.4 meV / A
# 2023-07-26 15:49:29.677 INFO: Epoch 19: loss=9.0289, RMSE_E_per_atom=60.9 meV, RMSE_F=219.4 meV / A
# 2023-07-26 15:50:01.802 INFO: Epoch 20: loss=6.8535, RMSE_E_per_atom=40.9 meV, RMSE_F=216.5 meV / A
# 2023-07-26 15:50:27.771 INFO: Epoch 21: loss=5.8858, RMSE_E_per_atom=29.6 meV, RMSE_F=213.2 meV / A
# 2023-07-26 15:51:00.649 INFO: Epoch 22: loss=5.4549, RMSE_E_per_atom=22.9 meV, RMSE_F=211.5 meV / A
# 2023-07-26 15:51:28.156 INFO: Epoch 23: loss=5.1917, RMSE_E_per_atom=18.6 meV, RMSE_F=209.6 meV / A
# 2023-07-26 15:51:55.411 INFO: Epoch 24: loss=5.0098, RMSE_E_per_atom=15.6 meV, RMSE_F=207.9 meV / A
# 2023-07-26 15:52:22.102 INFO: Epoch 25: loss=4.9154, RMSE_E_per_atom=14.5 meV, RMSE_F=206.6 meV / A
# 2023-07-26 15:52:43.014 INFO: Epoch 26: loss=4.7590, RMSE_E_per_atom=12.8 meV, RMSE_F=204.3 meV / A
# 2023-07-26 15:53:07.788 INFO: Epoch 27: loss=4.6794, RMSE_E_per_atom=12.2 meV, RMSE_F=202.9 meV / A
# 2023-07-26 15:53:33.425 INFO: Epoch 28: loss=4.6002, RMSE_E_per_atom=11.8 meV, RMSE_F=201.4 meV / A
# 2023-07-26 15:53:54.715 INFO: Epoch 29: loss=4.5635, RMSE_E_per_atom=11.5 meV, RMSE_F=200.7 meV / A
# 2023-07-26 15:53:54.738 INFO: Training complete
# 2023-07-26 15:53:54.740 INFO: Computing metrics for training, validation, and test sets
# 2023-07-26 15:53:54.753 INFO: Loading checkpoint: checkpoints/model_run-1234_epoch-14.pt
# 2023-07-26 15:53:54.770 INFO: Loaded model from epoch 14
# 2023-07-26 15:53:55.086 INFO: Evaluating train ...
# 2023-07-26 15:54:04.129 INFO: Evaluating valid ...
# 2023-07-26 15:54:05.085 INFO: Evaluating Default ...
# 2023-07-26 15:54:14.949 INFO:
# +-------------+---------------------+------------------+-------------------+
# | config_type | RMSE E / meV / atom | RMSE F / meV / A | relative F RMSE % |
# +-------------+---------------------+------------------+-------------------+
# |    train    |        718.6        |      273.6       |       12.10       |
# |    valid    |        712.9        |      229.1       |       17.76       |
# |   Default   |        733.9        |      149.6       |        5.51       |
# +-------------+---------------------+------------------+-------------------+
# 2023-07-26 15:54:14.950 INFO: Saving model to checkpoints/model_run-1234.model
# 2023-07-26 15:54:15.055 INFO: Loading checkpoint: checkpoints/model_run-1234_epoch-29_swa.pt
# 2023-07-26 15:54:15.077 INFO: Loaded model from epoch 29
# 2023-07-26 15:54:15.860 INFO: Evaluating train ...
# 2023-07-26 15:54:26.305 INFO: Evaluating valid ...
# 2023-07-26 15:54:27.583 INFO: Evaluating Default ...
# 2023-07-26 15:54:35.891 INFO:
# +-------------+---------------------+------------------+-------------------+
# | config_type | RMSE E / meV / atom | RMSE F / meV / A | relative F RMSE % |
# +-------------+---------------------+------------------+-------------------+
# |    train    |         9.7         |      232.6       |       10.28       |
# |    valid    |         11.5        |      200.7       |       15.56       |
# |   Default   |         0.0         |       0.0        |        0.00       |
# +-------------+---------------------+------------------+-------------------+
# 2023-07-26 15:54:35.901 INFO: Saving model to checkpoints/model_run-1234_swa.model
# 2023-07-26 15:54:36.013 INFO: Done

# %% [markdown]
# # Testing MACE vs GAP

# %% [markdown]
# We will now evaluate the trained model on the test datasets we explored yesterday. For this, we can use the eval_configs.py code. One needs to specify the file to evaluate in `--configs`. The path to the model is in `--model`. The `--output` specifies to path of the output file where the predicted energies and forces of MACE are stored. The `--default_dtype="float32"`needs to match the one you used for training.

# %%
#evaluate the train set

# !python3 ./mace/scripts/eval_configs.py \
    --configs="data/solvent_mace_train.xyz" \
    --model="model_swa.model" \
    --output="maceTests/solvent_train.xyz" \
    --default_dtype="float32" \
    --info_prefix=""

#evaluate the test set
# !python3 ./mace/scripts/eval_configs.py \
    --configs="data/solvent_mace_test.xyz" \
    --model="model_swa.model" \
    --output="maceTests/solvent_test.xyz" \
    --default_dtype="float32" \
    --info_prefix=""

#evaluate the volume scan
# !python3 ./mace/scripts/eval_configs.py \
    --configs="data/volumeScan.xyz" \
    --model="model_swa.model" \
    --output="maceTests/volumeScan.xyz" \
    --default_dtype="float32" \
    --info_prefix=""

# %% [markdown]
# We can compare MACE vs GAP accuracy on the train and test sets.

# %%
from aseMolec import pltProps as pp
from ase.io import read
import matplotlib.pyplot as plt
from aseMolec import extAtoms as ea 
import numpy as np

def plot_RMSEs(db1, db2, labs):
    plt.figure(figsize=(8,4), dpi=100)
    plt.subplot(1,2,1)
    pp.plot_prop(ea.get_prop(db1, 'info', 'energy', True).flatten(), \
                 ea.get_prop(db2, 'info', 'energy', True).flatten(), \
                 title=r'Energy $(\rm eV/atom)$ ', labs=labs, rel=True)
    plt.subplot(1,2,2)
    pp.plot_prop(np.concatenate(ea.get_prop(db1, 'arrays', 'forces')).flatten(), \
                 np.concatenate(ea.get_prop(db2, 'arrays', 'forces')).flatten(), \
                 title=r'Forces $\rm (eV/\AA)$ ', labs=labs, rel=True)
    plt.tight_layout()
    return

plot_RMSEs(read('data/solvent_mace_test.xyz', ':'), read('maceTests/solvent_test.xyz', ':'), labs=['XTB', 'MACE'])
plot_RMSEs(read('data/solvent_test.xyz', ':'), read('gapTests/solvent_test.xyz', ':'), labs=['XTB', 'GAP'])

# %% [markdown]
# MACE forces are twice as good! More importantly, MACE effective cutoff is larger than 3 A, do you recall what happed in GAP when we extend the cutoff?
#
# We can also check the Intra/Inter splits:

# %%
from aseMolec import pltProps as pp
from aseMolec import anaAtoms as aa

db1 = read('data/solvent_mace_test.xyz', ':')
db2 = read('maceTests/solvent_test.xyz', ':')

aa.extract_molecs(db1, intra_inter=True)
aa.extract_molecs(db2, intra_inter=True)

pp.plot_trans_rot_vib(db1, db2, labs=['XTB', 'MACE'])

db1 = read('data/solvent_test.xyz', ':')
aa.extract_molecs(db1, intra_inter=True)
ea.check_keys(db1[:1])
db2 = read('gapTests/solvent_test.xyz', ':')
aa.extract_molecs(db2, intra_inter=True)

pp.plot_trans_rot_vib(db1, db2, labs=['XTB', 'GAP'])
# Out:
# ['Nmols', 'Comp', 'energy', 'numbers', 'positions', 'molID', 'forces', 'forces_trans', 'forces_rot', 'forces_vib']

# %% [markdown]
# Again, MACE performs better. However, iner-molecular are still difficult to capture - as we expect.

# %%
import numpy as np
from matplotlib import pyplot as plt
from aseMolec import extAtoms as ea

def plot_vscan(vsname='volumeScan', vspaths=['data', 'gapTests', 'maceTests']):
    for i, vspath in enumerate(vspaths):
        db = read(vspath+'/'+vsname+'.xyz', ':')
        config = np.arange(len(db))
        energy = ea.get_prop(db, 'info', 'energy', peratom=True)
        plt.plot(config, energy, '.-', label=vspath, alpha=0.5)
    plt.xlabel(r'Volume Scan Config')
    plt.ylabel(r'Energy ($\rm eV/atom$)')
    plt.legend()
    plt.title(vsname)
    plt.tight_layout()

plot_vscan()

# %% [markdown]
# The `volume scan` is still not perfect, but MACE is smoother! More data will be needed to get this right.

# %% [markdown]
# # Molecular Dynamics with MACE

# %% [markdown]
# MD is the ultimate test, let's check MACE stability. We will start by implementing a simple function to run Langevin dynamics. We will initialize the temperature at 300 K and remove all translations and rotations.

# %%
from ase.io import read, write
from ase import units
from ase.md.langevin import Langevin
from ase.md.velocitydistribution import Stationary, ZeroRotation, MaxwellBoltzmannDistribution

import random
import os
import time
import numpy as np
import pylab as pl
from IPython import display

def simpleMD(init_conf, temp, calc, fname, s, T):
    init_conf.set_calculator(calc)

    #initialize the temperature
    random.seed(701) #just making sure the MD failure is reproducible
    MaxwellBoltzmannDistribution(init_conf, temperature_K=300) #initialize temperature at 300
    Stationary(init_conf)
    ZeroRotation(init_conf)

    dyn = Langevin(init_conf, 1.0*units.fs, temperature_K=temp, friction=0.1) #drive system to desired temperature

    # %matplotlib inline

    time_fs = []
    temperature = []
    energies = []

    #remove previously stored trajectory with the same name
    os.system('rm -rfv '+fname)

    fig, ax = pl.subplots(2, 1, figsize=(6,6), sharex='all', gridspec_kw={'hspace': 0, 'wspace': 0})

    def write_frame():
            dyn.atoms.write(fname, append=True)
            time_fs.append(dyn.get_time()/units.fs)
            temperature.append(dyn.atoms.get_temperature())
            energies.append(dyn.atoms.get_potential_energy()/len(dyn.atoms))

            ax[0].plot(np.array(time_fs), np.array(energies), color="b")
            ax[0].set_ylabel('E (eV/atom)')

            # plot the temperature of the system as subplots
            ax[1].plot(np.array(time_fs), temperature, color="r")
            ax[1].set_ylabel('T (K)')
            ax[1].set_xlabel('Time (fs)')

            display.clear_output(wait=True)
            display.display(pl.gcf())
            time.sleep(0.01)

    dyn.attach(write_frame, interval=s)
    t0 = time.time()
    dyn.run(T)
    t1 = time.time()
    print("MD finished in {0:.2f} minutes!".format((t1-t0)/60))

# %% [markdown]
# ## Compare MACE, GAP and XTB Dynamics

# %% [markdown]
# Now we can run MD with MACE. Let's try 2 picoseoncds starting from a single molecule config:

# %%
 #let us start with a single molecule
init_conf = ea.sel_by_info_val(read('data/solvent_molecs.xyz',':'), 'Nmols', 1)[0].copy()

#we can use MACE as a calculator in ASE!
from mace.calculators import MACECalculator
mace_calc = MACECalculator(model_paths=['model_swa.model'], device='cpu', default_dtype="float32")


simpleMD(init_conf, temp=1200, calc=mace_calc, fname='mace_md.xyz', s=10, T=2000)
# Out:
# MD finished in 8.50 minutes!

# %% [markdown]
# Let's also run some dynamics with the GAP potential we fitted yesterday.

# %%
# reinitialize the original config
init_conf = ea.sel_by_info_val(read('data/solvent_molecs.xyz',':'), 'Nmols', 1)[0].copy()

#we can use GAP as a calculator in ASE!
from quippy.potential import Potential
gap_calc = Potential("", param_filename="gapModels/GAP.xml")

simpleMD(init_conf, temp=1200, calc=gap_calc, fname='gap_md.xyz', s=10, T=2000)
# Out:
# MD finished in 10.07 minutes!

# %% [markdown]
# For reference, we can also run XTB dynamics from the same starting configuration.

# %%
# reinitialize the original config
init_conf = ea.sel_by_info_val(read('data/solvent_molecs.xyz',':'), 'Nmols', 1)[0].copy()

from xtb.ase.calculator import XTB
xtb_calc = XTB(method="GFN2-xTB")

simpleMD(init_conf, temp=1200, calc=xtb_calc, fname='xtb_md.xyz', s=10, T=2000)
# Out:
# MD finished in 22.78 minutes!

# %% [markdown]
# Great the dynamics are pretty stable! Download the trajectory files `.xyz` and visualize them with your favourite software.
#
# Are the different dynamics sampling the correct distributions? Let us check the radial distribution functions (RDF). The [aseMolec](https://github.com/imagdau/aseMolec) package provides functionality to do that:

# %%
from aseMolec import anaAtoms as aa

tag = 'HO_intra' #choose one of 'HH_intra', 'HC_intra', 'HO_intra', 'CC_intra', 'CO_intra', 'OO_intra'

for f in ['xtb_md', 'mace_md', 'gap_md']:
    traj = read(f+'.xyz', ':')
    for at in traj:
        at.pbc = True
        at.cell = [100,100,100]
    rdf = aa.compute_rdfs_traj_avg(traj, rmax=5, nbins=50) #aseMolec provides functionality to compute RDFs
    plt.plot(rdf[1], rdf[0][tag], label=f, alpha=0.7, linewidth=3)

plt.legend();
plt.yticks([]);
plt.xlabel(r'R ($\rm \AA$)');
plt.ylabel('RDF '+tag);

# %% [markdown]
# Try it yourself! Look at other RDF types, how well are they reproduced? The MACE model performes better than GAP.
#
# The trajectories here are pretty stable, but this is a pretty simple problem. We chose a single molecule at relatively small temperatures (for a molecule) and only ran for 2 picoseconds. In practice, given enough time and high enough temperature the initial models will fail.
#
# Experiment with the starting configs, temperatures, simulation length, see if you can find problems with the potentials!

# %% [markdown]
# ## The Molecular Liquid Condensed Phase

# %% [markdown]
# The MLIP was trained on clusters, can we simulate the liquid molecular environment?

# %%
init_conf = read('data/ECEMC.xyz','4') #read a liquid config with periodic boundary conditions
init_conf.center()

simpleMD(init_conf, temp=500, calc=mace_calc, fname='liquid_md.xyz', s=10, T=2000)
# Out:
# MD finished in 8.24 minutes!

# %% [markdown]
# This XTB calculator is non-periodic, so this dynamics would not be possible without an MLIP! Check for yourself, by replacing the calculator with xtb. The system is much larger than the example before (12 molecules vs just one), check how GAP scales with size by replacing the calculator with gap.
#
#
# Transferability from clusters to the condensed phase environment is still an open research question. If this works, it implies that we might be able to learn on highly accuracte Quantum Chemistry methods on molecular clusters and make predictions (density, diffusivity) for the condensed phase! This is new Science!

# %% [markdown]
# # Active Learning with MACE
#
# This is a short tutorial on how to use active learning with MACE.
#
# Active learning consists is an iterative fitting process aiming at providing the model with the most optimal training data for increasing its performance. For any active learning sheme, two things are essential:
#
# - A efficient data generation source, in our case molecular dynamics.
# - A score function rating the utility of a given data to be trained
#
# The score function in the case of interatomic potentials is usually correlated to the uncertainty of the prediction of the model for a given configuration. For neural networks potentials like MACE, a straightforward measure of uncertainty is the variance of the output over an ensemble of models.

# %% [markdown]
# To obtain a comittee from MACE, we need to train a committee of models and add some randomness to the optimization process. We can achieve this by changing the `--seed`.
#
# Let us train three small MACE models to make sure they break for demo purposes. We will use different seeds for the three independent models. This will allow us to create a `comittee` of independent predictors. As we change hyper parameters, we will also change the `--name` of the model to make sure it saves seperatly.

# %%
#prepare a much smaller training example, and let us pick independent data sets
from ase.io import read, write
db = read('data/solvent_xtb.xyz', ':')
write('data/solvent_mace_small1_train.xyz', db[:3]+db[3:53]) #
write('data/solvent_mace_small2_train.xyz', db[:3]+db[53:103])
write('data/solvent_mace_small3_train.xyz', db[:3]+db[103:153])

#train the first model
# !python3 ./mace/scripts/run_train.py \
    --name="model_small1" \
    --train_file="data/solvent_mace_small1_train.xyz" \
    --valid_fraction=0.05 \
    --E0s="isolated" \
    --energy_key="energy" \
    --forces_key="forces" \
    --model="MACE" \
    --num_interactions=2 \
    --max_ell=2 \
    --hidden_irreps="16x0e" \
    --num_cutoff_basis=5 \
    --correlation=2 \
    --r_max=3.0 \
    --batch_size=5 \
    --valid_batch_size=5 \
    --eval_interval=1 \
    --max_num_epochs=50 \
    --start_swa=30 \
    --swa_energy_weight=1000 \
    --ema \
    --ema_decay=0.99 \
    --amsgrad \
    --error_table="PerAtomRMSE" \
    --default_dtype="float32" \
    --swa \
    --device=cpu \
    --seed=345

#train the second model
# !python3 ./mace/scripts/run_train.py \
    --name="model_small2" \
    --train_file="data/solvent_mace_small2_train.xyz" \
    --valid_fraction=0.05 \
    --E0s="isolated" \
    --energy_key="energy" \
    --forces_key="forces" \
    --model="MACE" \
    --num_interactions=2 \
    --max_ell=2 \
    --hidden_irreps="16x0e" \
    --num_cutoff_basis=5 \
    --correlation=2 \
    --r_max=3.0 \
    --batch_size=5 \
    --valid_batch_size=5 \
    --eval_interval=1 \
    --max_num_epochs=50 \
    --start_swa=30 \
    --swa_energy_weight=1000 \
    --ema \
    --ema_decay=0.99 \
    --amsgrad \
    --error_table="PerAtomRMSE" \
    --default_dtype="float32" \
    --swa \
    --device=cpu \
    --seed=567

#train the thirds model
# !python3 ./mace/scripts/run_train.py \
    --name="model_small3" \
    --train_file="data/solvent_mace_small3_train.xyz" \
    --valid_fraction=0.05 \
    --E0s="isolated" \
    --energy_key="energy" \
    --forces_key="forces" \
    --model="MACE" \
    --num_interactions=2 \
    --max_ell=2 \
    --hidden_irreps="16x0e" \
    --num_cutoff_basis=5 \
    --correlation=2 \
    --r_max=3.0 \
    --batch_size=5 \
    --valid_batch_size=5 \
    --eval_interval=1 \
    --max_num_epochs=50 \
    --start_swa=30 \
    --swa_energy_weight=1000 \
    --ema \
    --ema_decay=0.99 \
    --amsgrad \
    --error_table="PerAtomRMSE" \
    --default_dtype="float32" \
    --swa \
    --device=cpu \
    --seed=731
# Out:
# 2023-07-26 16:45:43.704 INFO: MACE version: 0.2.0
# 2023-07-26 16:45:43.704 INFO: Configuration: Namespace(name='model_small1', seed=345, log_dir='logs', model_dir='.', checkpoints_dir='checkpoints', results_dir='results', downloads_dir='downloads', device='cpu', default_dtype='float32', log_level='INFO', error_table='PerAtomRMSE', model='MACE', r_max=3.0, num_radial_basis=8, num_cutoff_basis=5, interaction='RealAgnosticResidualInteractionBlock', interaction_first='RealAgnosticResidualInteractionBlock', max_ell=2, correlation=2, num_interactions=2, MLP_irreps='16x0e', radial_MLP='[64, 64, 64]', hidden_irreps='16x0e', num_channels=None, max_L=None, gate='silu', scaling='rms_forces_scaling', avg_num_neighbors=1, compute_avg_num_neighbors=True, compute_stress=False, compute_forces=True, train_file='data/solvent_mace_small1_train.xyz', valid_file=None, valid_fraction=0.05, test_file=None, E0s='isolated', energy_key='energy', forces_key='forces', virials_key='virials', stress_key='stress', dipole_key='dipole', charges_key='charges', loss='weighted', forces_weight=100.0, swa_forces_weight=100.0, energy_weight=1.0, swa_energy_weight=1000.0, virials_weight=1.0, swa_virials_weight=10.0, stress_weight=1.0, swa_stress_weight=10.0, dipole_weight=1.0, swa_dipole_weight=1.0, config_type_weights='{"Default":1.0}', huber_delta=0.01, optimizer='adam', batch_size=5, valid_batch_size=5, lr=0.01, swa_lr=0.001, weight_decay=5e-07, amsgrad=True, scheduler='ReduceLROnPlateau', lr_factor=0.8, scheduler_patience=50, lr_scheduler_gamma=0.9993, swa=True, start_swa=30, ema=True, ema_decay=0.99, max_num_epochs=50, patience=2048, eval_interval=1, keep_checkpoints=False, restart_latest=False, save_cpu=False, clip_grad=10.0, wandb=False, wandb_project='', wandb_entity='', wandb_name='', wandb_log_hypers=['num_channels', 'max_L', 'correlation', 'lr', 'swa_lr', 'weight_decay', 'batch_size', 'max_num_epochs', 'start_swa', 'energy_weight', 'forces_weight'])
# 2023-07-26 16:45:43.704 INFO: Using CPU
# 2023-07-26 16:45:43.760 INFO: Using isolated atom energies from training file
# 2023-07-26 16:45:43.762 INFO: Loaded 50 training configurations from 'data/solvent_mace_small1_train.xyz'
# 2023-07-26 16:45:43.762 INFO: Using random 5.0% of training set for validation
# 2023-07-26 16:45:43.762 INFO: Total number of configurations: train=48, valid=2, tests=[]
# 2023-07-26 16:45:43.763 INFO: AtomicNumberTable: (1, 6, 8)
# 2023-07-26 16:45:43.763 INFO: Atomic energies: [-10.707211383396714, -48.847445262804705, -102.57117256025786]
# 2023-07-26 16:45:43.952 INFO: WeightedEnergyForcesLoss(energy_weight=1.000, forces_weight=100.000)
# 2023-07-26 16:45:43.995 INFO: Average number of neighbors: 6.92307710647583
# 2023-07-26 16:45:43.996 INFO: Selected the following outputs: {'energy': True, 'forces': True, 'virials': False, 'stress': False, 'dipoles': False}
# 2023-07-26 16:45:43.996 INFO: Building model
# 2023-07-26 16:45:43.996 INFO: Hidden irreps: 16x0e
# 2023-07-26 16:45:45.081 INFO: Using stochastic weight averaging (after 30 epochs) with energy weight : 1000.0, forces weight : 100.0 and learning rate : 0.001
# 2023-07-26 16:45:45.168 INFO: ScaleShiftMACE(
#   (node_embedding): LinearNodeEmbeddingBlock(
#     (linear): Linear(3x0e -> 16x0e | 48 weights)
#   )
#   (radial_embedding): RadialEmbeddingBlock(
#     (bessel_fn): BesselBasis(r_max=3.0, num_basis=8, trainable=False)
#     (cutoff_fn): PolynomialCutoff(p=5.0, r_max=3.0)
#   )
#   (spherical_harmonics): SphericalHarmonics()
#   (atomic_energies_fn): AtomicEnergiesBlock(energies=[-10.7072, -48.8474, -102.5712])
#   (interactions): ModuleList(
#     (0): RealAgnosticInteractionBlock(
#       (linear_up): Linear(16x0e -> 16x0e | 256 weights)
#       (conv_tp): TensorProduct(16x0e x 1x0e+1x1o+1x2e -> 16x0e+16x1o+16x2e | 48 paths | 48 weights)
#       (conv_tp_weights): FullyConnectedNet[8, 64, 64, 64, 48]
#       (linear): Linear(16x0e+16x1o+16x2e -> 16x0e+16x1o+16x2e | 768 weights)
#       (skip_tp): FullyConnectedTensorProduct(16x0e+16x1o+16x2e x 3x0e -> 16x0e+16x1o+16x2e | 2304 paths | 2304 weights)
#       (reshape): reshape_irreps()
#     )
#     (1): RealAgnosticResidualInteractionBlock(
#       (linear_up): Linear(16x0e -> 16x0e | 256 weights)
#       (conv_tp): TensorProduct(16x0e x 1x0e+1x1o+1x2e -> 16x0e+16x1o+16x2e | 48 paths | 48 weights)
#       (conv_tp_weights): FullyConnectedNet[8, 64, 64, 64, 48]
#       (linear): Linear(16x0e+16x1o+16x2e -> 16x0e+16x1o+16x2e | 768 weights)
#       (skip_tp): FullyConnectedTensorProduct(16x0e x 3x0e -> 16x0e | 768 paths | 768 weights)
#       (reshape): reshape_irreps()
#     )
#   )
#   (products): ModuleList(
#     (0): EquivariantProductBasisBlock(
#       (symmetric_contractions): SymmetricContraction(
#         (contractions): ModuleList(
#           (0): Contraction(
#             (contractions_weighting): ModuleList(
#               (0): GraphModule()
#             )
#             (contractions_features): ModuleList(
#               (0): GraphModule()
#             )
#             (weights): ParameterList(  (0): Parameter containing: [torch.FloatTensor of size 3x1x16])
#             (graph_opt_main): GraphModule()
#           )
#         )
#       )
#       (linear): Linear(16x0e -> 16x0e | 256 weights)
#     )
#     (1): EquivariantProductBasisBlock(
#       (symmetric_contractions): SymmetricContraction(
#         (contractions): ModuleList(
#           (0): Contraction(
#             (contractions_weighting): ModuleList(
#               (0): GraphModule()
#             )
#             (contractions_features): ModuleList(
#               (0): GraphModule()
#             )
#             (weights): ParameterList(  (0): Parameter containing: [torch.FloatTensor of size 3x1x16])
#             (graph_opt_main): GraphModule()
#           )
#         )
#       )
#       (linear): Linear(16x0e -> 16x0e | 256 weights)
#     )
#   )
#   (readouts): ModuleList(
#     (0): LinearReadoutBlock(
#       (linear): Linear(16x0e -> 1x0e | 16 weights)
#     )
#     (1): NonLinearReadoutBlock(
#       (linear_1): Linear(16x0e -> 16x0e | 256 weights)
#       (non_linearity): Activation [x] (16x0e -> 16x0e)
#       (linear_2): Linear(16x0e -> 1x0e | 16 weights)
#     )
#   )
#   (scale_shift): ScaleShiftBlock(scale=1.772527, shift=0.000000)
# )
# 2023-07-26 16:45:45.170 INFO: Number of parameters: 29904
# 2023-07-26 16:45:45.170 INFO: Optimizer: Adam (
# Parameter Group 0
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: embedding
#     swa_lr: 0.001
#     weight_decay: 0.0
#
# Parameter Group 1
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: interactions_decay
#     swa_lr: 0.001
#     weight_decay: 5e-07
#
# Parameter Group 2
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: interactions_no_decay
#     swa_lr: 0.001
#     weight_decay: 0.0
#
# Parameter Group 3
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: products
#     swa_lr: 0.001
#     weight_decay: 5e-07
#
# Parameter Group 4
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: readouts
#     swa_lr: 0.001
#     weight_decay: 0.0
# )
# 2023-07-26 16:45:45.170 INFO: Using gradient clipping with tolerance=10.000
# 2023-07-26 16:45:45.170 INFO: Started training
# 2023-07-26 16:45:51.166 INFO: Epoch 0: loss=167.9280, RMSE_E_per_atom=5499.5 meV, RMSE_F=1173.4 meV / A
# 2023-07-26 16:45:52.718 INFO: Epoch 1: loss=140.2327, RMSE_E_per_atom=5468.2 meV, RMSE_F=1050.4 meV / A
# 2023-07-26 16:45:54.976 INFO: Epoch 2: loss=124.0686, RMSE_E_per_atom=5320.9 meV, RMSE_F=978.6 meV / A
# 2023-07-26 16:45:57.348 INFO: Epoch 3: loss=110.8633, RMSE_E_per_atom=5201.6 meV, RMSE_F=915.5 meV / A
# 2023-07-26 16:45:59.861 INFO: Epoch 4: loss=105.5734, RMSE_E_per_atom=5158.2 meV, RMSE_F=888.6 meV / A
# 2023-07-26 16:46:01.476 INFO: Epoch 5: loss=98.5727, RMSE_E_per_atom=5060.9 meV, RMSE_F=854.2 meV / A
# 2023-07-26 16:46:02.777 INFO: Epoch 6: loss=93.2271, RMSE_E_per_atom=5022.2 meV, RMSE_F=824.6 meV / A
# 2023-07-26 16:46:04.054 INFO: Epoch 7: loss=85.1731, RMSE_E_per_atom=5000.8 meV, RMSE_F=775.7 meV / A
# 2023-07-26 16:46:05.359 INFO: Epoch 8: loss=76.7849, RMSE_E_per_atom=4964.7 meV, RMSE_F=722.1 meV / A
# 2023-07-26 16:46:07.277 INFO: Epoch 9: loss=68.4080, RMSE_E_per_atom=4956.7 meV, RMSE_F=662.1 meV / A
# 2023-07-26 16:46:08.634 INFO: Epoch 10: loss=60.3047, RMSE_E_per_atom=4926.5 meV, RMSE_F=600.3 meV / A
# 2023-07-26 16:46:09.936 INFO: Epoch 11: loss=55.3537, RMSE_E_per_atom=4856.6 meV, RMSE_F=563.6 meV / A
# 2023-07-26 16:46:11.232 INFO: Epoch 12: loss=50.4490, RMSE_E_per_atom=4790.9 meV, RMSE_F=524.4 meV / A
# 2023-07-26 16:46:12.542 INFO: Epoch 13: loss=46.2765, RMSE_E_per_atom=4718.6 meV, RMSE_F=490.0 meV / A
# 2023-07-26 16:46:13.837 INFO: Epoch 14: loss=43.0694, RMSE_E_per_atom=4629.3 meV, RMSE_F=465.2 meV / A
# 2023-07-26 16:46:16.017 INFO: Epoch 15: loss=38.8051, RMSE_E_per_atom=4505.7 meV, RMSE_F=430.2 meV / A
# 2023-07-26 16:46:18.829 INFO: Epoch 16: loss=36.3093, RMSE_E_per_atom=4410.0 meV, RMSE_F=410.6 meV / A
# 2023-07-26 16:46:21.087 INFO: Epoch 17: loss=32.8128, RMSE_E_per_atom=4274.9 meV, RMSE_F=381.3 meV / A
# 2023-07-26 16:46:22.584 INFO: Epoch 18: loss=30.4138, RMSE_E_per_atom=4140.3 meV, RMSE_F=364.3 meV / A
# 2023-07-26 16:46:24.257 INFO: Epoch 19: loss=28.2616, RMSE_E_per_atom=4011.8 meV, RMSE_F=348.8 meV / A
# 2023-07-26 16:46:26.154 INFO: Epoch 20: loss=27.3354, RMSE_E_per_atom=3924.4 meV, RMSE_F=345.5 meV / A
# 2023-07-26 16:46:29.066 INFO: Epoch 21: loss=26.0999, RMSE_E_per_atom=3803.8 meV, RMSE_F=341.0 meV / A
# 2023-07-26 16:46:31.877 INFO: Epoch 22: loss=25.2742, RMSE_E_per_atom=3720.6 meV, RMSE_F=338.1 meV / A
# 2023-07-26 16:46:34.861 INFO: Epoch 23: loss=24.4282, RMSE_E_per_atom=3654.8 meV, RMSE_F=332.7 meV / A
# 2023-07-26 16:46:36.937 INFO: Epoch 24: loss=23.5809, RMSE_E_per_atom=3570.9 meV, RMSE_F=329.1 meV / A
# 2023-07-26 16:46:39.453 INFO: Epoch 25: loss=22.1792, RMSE_E_per_atom=3444.7 meV, RMSE_F=321.1 meV / A
# 2023-07-26 16:46:42.509 INFO: Epoch 26: loss=20.6542, RMSE_E_per_atom=3323.5 meV, RMSE_F=310.0 meV / A
# 2023-07-26 16:46:44.746 INFO: Epoch 27: loss=19.3812, RMSE_E_per_atom=3215.6 meV, RMSE_F=300.7 meV / A
# 2023-07-26 16:46:47.379 INFO: Epoch 28: loss=18.3186, RMSE_E_per_atom=3118.0 meV, RMSE_F=293.2 meV / A
# 2023-07-26 16:46:49.950 INFO: Epoch 29: loss=17.8808, RMSE_E_per_atom=3036.9 meV, RMSE_F=294.2 meV / A
# 2023-07-26 16:46:49.966 INFO: Changing loss based on SWA
# 2023-07-26 16:46:52.103 INFO: Epoch 30: loss=8578.1875, RMSE_E_per_atom=2927.3 meV, RMSE_F=298.3 meV / A
# 2023-07-26 16:46:53.987 INFO: Epoch 31: loss=7369.1665, RMSE_E_per_atom=2712.3 meV, RMSE_F=354.0 meV / A
# 2023-07-26 16:46:56.355 INFO: Epoch 32: loss=5625.3599, RMSE_E_per_atom=2366.2 meV, RMSE_F=513.9 meV / A
# 2023-07-26 16:46:58.763 INFO: Epoch 33: loss=3644.6458, RMSE_E_per_atom=1894.0 meV, RMSE_F=757.1 meV / A
# 2023-07-26 16:47:01.611 INFO: Epoch 34: loss=2140.2683, RMSE_E_per_atom=1437.1 meV, RMSE_F=866.0 meV / A
# 2023-07-26 16:47:03.745 INFO: Epoch 35: loss=1312.9116, RMSE_E_per_atom=1117.5 meV, RMSE_F=801.2 meV / A
# 2023-07-26 16:47:05.063 INFO: Epoch 36: loss=756.3529, RMSE_E_per_atom=838.8 meV, RMSE_F=726.0 meV / A
# 2023-07-26 16:47:06.687 INFO: Epoch 37: loss=416.6056, RMSE_E_per_atom=612.2 meV, RMSE_F=647.0 meV / A
# 2023-07-26 16:47:09.146 INFO: Epoch 38: loss=243.0045, RMSE_E_per_atom=455.3 meV, RMSE_F=597.4 meV / A
# 2023-07-26 16:47:11.848 INFO: Epoch 39: loss=145.9704, RMSE_E_per_atom=340.2 meV, RMSE_F=549.8 meV / A
# 2023-07-26 16:47:13.756 INFO: Epoch 40: loss=86.5114, RMSE_E_per_atom=245.7 meV, RMSE_F=511.2 meV / A
# 2023-07-26 16:47:15.947 INFO: Epoch 41: loss=60.0971, RMSE_E_per_atom=190.6 meV, RMSE_F=487.4 meV / A
# 2023-07-26 16:47:19.122 INFO: Epoch 42: loss=40.2348, RMSE_E_per_atom=137.2 meV, RMSE_F=462.8 meV / A
# 2023-07-26 16:47:21.952 INFO: Epoch 43: loss=29.4878, RMSE_E_per_atom=101.2 meV, RMSE_F=438.8 meV / A
# 2023-07-26 16:47:24.544 INFO: Epoch 44: loss=23.1921, RMSE_E_per_atom=75.4 meV, RMSE_F=418.4 meV / A
# 2023-07-26 16:47:27.087 INFO: Epoch 45: loss=18.5645, RMSE_E_per_atom=53.5 meV, RMSE_F=396.2 meV / A
# 2023-07-26 16:47:29.273 INFO: Epoch 46: loss=15.6293, RMSE_E_per_atom=37.6 meV, RMSE_F=377.0 meV / A
# 2023-07-26 16:47:31.854 INFO: Epoch 47: loss=13.6689, RMSE_E_per_atom=26.3 meV, RMSE_F=360.2 meV / A
# 2023-07-26 16:47:34.086 INFO: Epoch 48: loss=12.3148, RMSE_E_per_atom=16.6 meV, RMSE_F=347.0 meV / A
# 2023-07-26 16:47:36.168 INFO: Epoch 49: loss=11.3422, RMSE_E_per_atom=10.0 meV, RMSE_F=335.3 meV / A
# 2023-07-26 16:47:36.180 INFO: Training complete
# 2023-07-26 16:47:36.183 INFO: Computing metrics for training, validation, and test sets
# 2023-07-26 16:47:36.185 INFO: Loading checkpoint: checkpoints/model_small1_run-345_epoch-29.pt
# 2023-07-26 16:47:36.209 INFO: Loaded model from epoch 29
# 2023-07-26 16:47:36.366 INFO: Evaluating train ...
# 2023-07-26 16:47:38.372 INFO: Evaluating valid ...
# 2023-07-26 16:47:38.527 INFO:
# +-------------+---------------------+------------------+-------------------+
# | config_type | RMSE E / meV / atom | RMSE F / meV / A | relative F RMSE % |
# +-------------+---------------------+------------------+-------------------+
# |    train    |        3394.6       |      357.7       |       19.83       |
# |    valid    |        3036.9       |      294.2       |       22.72       |
# +-------------+---------------------+------------------+-------------------+
# 2023-07-26 16:47:38.527 INFO: Saving model to checkpoints/model_small1_run-345.model
# 2023-07-26 16:47:38.601 INFO: Loading checkpoint: checkpoints/model_small1_run-345_epoch-49_swa.pt
# 2023-07-26 16:47:38.617 INFO: Loaded model from epoch 49
# 2023-07-26 16:47:38.766 INFO: Evaluating train ...
# 2023-07-26 16:47:39.740 INFO: Evaluating valid ...
# 2023-07-26 16:47:39.890 INFO:
# +-------------+---------------------+------------------+-------------------+
# | config_type | RMSE E / meV / atom | RMSE F / meV / A | relative F RMSE % |
# +-------------+---------------------+------------------+-------------------+
# |    train    |        105.6        |      584.7       |       32.41       |
# |    valid    |         10.0        |      335.3       |       25.89       |
# +-------------+---------------------+------------------+-------------------+
# 2023-07-26 16:47:39.890 INFO: Saving model to checkpoints/model_small1_run-345_swa.model
# 2023-07-26 16:47:39.991 INFO: Done
# 2023-07-26 16:47:45.520 INFO: MACE version: 0.2.0
# 2023-07-26 16:47:45.520 INFO: Configuration: Namespace(name='model_small2', seed=567, log_dir='logs', model_dir='.', checkpoints_dir='checkpoints', results_dir='results', downloads_dir='downloads', device='cpu', default_dtype='float32', log_level='INFO', error_table='PerAtomRMSE', model='MACE', r_max=3.0, num_radial_basis=8, num_cutoff_basis=5, interaction='RealAgnosticResidualInteractionBlock', interaction_first='RealAgnosticResidualInteractionBlock', max_ell=2, correlation=2, num_interactions=2, MLP_irreps='16x0e', radial_MLP='[64, 64, 64]', hidden_irreps='16x0e', num_channels=None, max_L=None, gate='silu', scaling='rms_forces_scaling', avg_num_neighbors=1, compute_avg_num_neighbors=True, compute_stress=False, compute_forces=True, train_file='data/solvent_mace_small2_train.xyz', valid_file=None, valid_fraction=0.05, test_file=None, E0s='isolated', energy_key='energy', forces_key='forces', virials_key='virials', stress_key='stress', dipole_key='dipole', charges_key='charges', loss='weighted', forces_weight=100.0, swa_forces_weight=100.0, energy_weight=1.0, swa_energy_weight=1000.0, virials_weight=1.0, swa_virials_weight=10.0, stress_weight=1.0, swa_stress_weight=10.0, dipole_weight=1.0, swa_dipole_weight=1.0, config_type_weights='{"Default":1.0}', huber_delta=0.01, optimizer='adam', batch_size=5, valid_batch_size=5, lr=0.01, swa_lr=0.001, weight_decay=5e-07, amsgrad=True, scheduler='ReduceLROnPlateau', lr_factor=0.8, scheduler_patience=50, lr_scheduler_gamma=0.9993, swa=True, start_swa=30, ema=True, ema_decay=0.99, max_num_epochs=50, patience=2048, eval_interval=1, keep_checkpoints=False, restart_latest=False, save_cpu=False, clip_grad=10.0, wandb=False, wandb_project='', wandb_entity='', wandb_name='', wandb_log_hypers=['num_channels', 'max_L', 'correlation', 'lr', 'swa_lr', 'weight_decay', 'batch_size', 'max_num_epochs', 'start_swa', 'energy_weight', 'forces_weight'])
# 2023-07-26 16:47:45.520 INFO: Using CPU
# 2023-07-26 16:47:45.582 INFO: Using isolated atom energies from training file
# 2023-07-26 16:47:45.584 INFO: Loaded 50 training configurations from 'data/solvent_mace_small2_train.xyz'
# 2023-07-26 16:47:45.584 INFO: Using random 5.0% of training set for validation
# 2023-07-26 16:47:45.584 INFO: Total number of configurations: train=48, valid=2, tests=[]
# 2023-07-26 16:47:45.584 INFO: AtomicNumberTable: (1, 6, 8)
# 2023-07-26 16:47:45.584 INFO: Atomic energies: [-10.707211383396714, -48.847445262804705, -102.57117256025786]
# 2023-07-26 16:47:45.698 INFO: WeightedEnergyForcesLoss(energy_weight=1.000, forces_weight=100.000)
# 2023-07-26 16:47:45.754 INFO: Average number of neighbors: 7.047918319702148
# 2023-07-26 16:47:45.754 INFO: Selected the following outputs: {'energy': True, 'forces': True, 'virials': False, 'stress': False, 'dipoles': False}
# 2023-07-26 16:47:45.755 INFO: Building model
# 2023-07-26 16:47:45.755 INFO: Hidden irreps: 16x0e
# 2023-07-26 16:47:47.093 INFO: Using stochastic weight averaging (after 30 epochs) with energy weight : 1000.0, forces weight : 100.0 and learning rate : 0.001
# 2023-07-26 16:47:47.183 INFO: ScaleShiftMACE(
#   (node_embedding): LinearNodeEmbeddingBlock(
#     (linear): Linear(3x0e -> 16x0e | 48 weights)
#   )
#   (radial_embedding): RadialEmbeddingBlock(
#     (bessel_fn): BesselBasis(r_max=3.0, num_basis=8, trainable=False)
#     (cutoff_fn): PolynomialCutoff(p=5.0, r_max=3.0)
#   )
#   (spherical_harmonics): SphericalHarmonics()
#   (atomic_energies_fn): AtomicEnergiesBlock(energies=[-10.7072, -48.8474, -102.5712])
#   (interactions): ModuleList(
#     (0): RealAgnosticInteractionBlock(
#       (linear_up): Linear(16x0e -> 16x0e | 256 weights)
#       (conv_tp): TensorProduct(16x0e x 1x0e+1x1o+1x2e -> 16x0e+16x1o+16x2e | 48 paths | 48 weights)
#       (conv_tp_weights): FullyConnectedNet[8, 64, 64, 64, 48]
#       (linear): Linear(16x0e+16x1o+16x2e -> 16x0e+16x1o+16x2e | 768 weights)
#       (skip_tp): FullyConnectedTensorProduct(16x0e+16x1o+16x2e x 3x0e -> 16x0e+16x1o+16x2e | 2304 paths | 2304 weights)
#       (reshape): reshape_irreps()
#     )
#     (1): RealAgnosticResidualInteractionBlock(
#       (linear_up): Linear(16x0e -> 16x0e | 256 weights)
#       (conv_tp): TensorProduct(16x0e x 1x0e+1x1o+1x2e -> 16x0e+16x1o+16x2e | 48 paths | 48 weights)
#       (conv_tp_weights): FullyConnectedNet[8, 64, 64, 64, 48]
#       (linear): Linear(16x0e+16x1o+16x2e -> 16x0e+16x1o+16x2e | 768 weights)
#       (skip_tp): FullyConnectedTensorProduct(16x0e x 3x0e -> 16x0e | 768 paths | 768 weights)
#       (reshape): reshape_irreps()
#     )
#   )
#   (products): ModuleList(
#     (0): EquivariantProductBasisBlock(
#       (symmetric_contractions): SymmetricContraction(
#         (contractions): ModuleList(
#           (0): Contraction(
#             (contractions_weighting): ModuleList(
#               (0): GraphModule()
#             )
#             (contractions_features): ModuleList(
#               (0): GraphModule()
#             )
#             (weights): ParameterList(  (0): Parameter containing: [torch.FloatTensor of size 3x1x16])
#             (graph_opt_main): GraphModule()
#           )
#         )
#       )
#       (linear): Linear(16x0e -> 16x0e | 256 weights)
#     )
#     (1): EquivariantProductBasisBlock(
#       (symmetric_contractions): SymmetricContraction(
#         (contractions): ModuleList(
#           (0): Contraction(
#             (contractions_weighting): ModuleList(
#               (0): GraphModule()
#             )
#             (contractions_features): ModuleList(
#               (0): GraphModule()
#             )
#             (weights): ParameterList(  (0): Parameter containing: [torch.FloatTensor of size 3x1x16])
#             (graph_opt_main): GraphModule()
#           )
#         )
#       )
#       (linear): Linear(16x0e -> 16x0e | 256 weights)
#     )
#   )
#   (readouts): ModuleList(
#     (0): LinearReadoutBlock(
#       (linear): Linear(16x0e -> 1x0e | 16 weights)
#     )
#     (1): NonLinearReadoutBlock(
#       (linear_1): Linear(16x0e -> 16x0e | 256 weights)
#       (non_linearity): Activation [x] (16x0e -> 16x0e)
#       (linear_2): Linear(16x0e -> 1x0e | 16 weights)
#     )
#   )
#   (scale_shift): ScaleShiftBlock(scale=2.586118, shift=0.000000)
# )
# 2023-07-26 16:47:47.185 INFO: Number of parameters: 29904
# 2023-07-26 16:47:47.185 INFO: Optimizer: Adam (
# Parameter Group 0
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: embedding
#     swa_lr: 0.001
#     weight_decay: 0.0
#
# Parameter Group 1
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: interactions_decay
#     swa_lr: 0.001
#     weight_decay: 5e-07
#
# Parameter Group 2
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: interactions_no_decay
#     swa_lr: 0.001
#     weight_decay: 0.0
#
# Parameter Group 3
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: products
#     swa_lr: 0.001
#     weight_decay: 5e-07
#
# Parameter Group 4
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: readouts
#     swa_lr: 0.001
#     weight_decay: 0.0
# )
# 2023-07-26 16:47:47.185 INFO: Using gradient clipping with tolerance=10.000
# 2023-07-26 16:47:47.185 INFO: Started training
# 2023-07-26 16:47:56.137 INFO: Epoch 0: loss=689.9247, RMSE_E_per_atom=5821.8 meV, RMSE_F=2561.3 meV / A
# 2023-07-26 16:47:59.032 INFO: Epoch 1: loss=350.2227, RMSE_E_per_atom=5673.4 meV, RMSE_F=1783.4 meV / A
# 2023-07-26 16:48:01.272 INFO: Epoch 2: loss=235.6762, RMSE_E_per_atom=5498.7 meV, RMSE_F=1433.3 meV / A
# 2023-07-26 16:48:03.580 INFO: Epoch 3: loss=217.0802, RMSE_E_per_atom=5375.5 meV, RMSE_F=1371.8 meV / A
# 2023-07-26 16:48:05.568 INFO: Epoch 4: loss=258.3940, RMSE_E_per_atom=5258.4 meV, RMSE_F=1519.0 meV / A
# 2023-07-26 16:48:07.678 INFO: Epoch 5: loss=291.7491, RMSE_E_per_atom=5103.1 meV, RMSE_F=1630.1 meV / A
# 2023-07-26 16:48:10.552 INFO: Epoch 6: loss=203.7776, RMSE_E_per_atom=5060.1 meV, RMSE_F=1334.8 meV / A
# 2023-07-26 16:48:13.164 INFO: Epoch 7: loss=208.1201, RMSE_E_per_atom=4968.0 meV, RMSE_F=1354.4 meV / A
# 2023-07-26 16:48:15.957 INFO: Epoch 8: loss=178.5037, RMSE_E_per_atom=4913.5 meV, RMSE_F=1242.4 meV / A
# 2023-07-26 16:48:18.748 INFO: Epoch 9: loss=130.9466, RMSE_E_per_atom=4853.3 meV, RMSE_F=1036.3 meV / A
# 2023-07-26 16:48:21.683 INFO: Epoch 10: loss=140.7461, RMSE_E_per_atom=4753.9 meV, RMSE_F=1087.0 meV / A
# 2023-07-26 16:48:24.282 INFO: Epoch 11: loss=106.0729, RMSE_E_per_atom=4708.6 meV, RMSE_F=916.0 meV / A
# 2023-07-26 16:48:26.682 INFO: Epoch 12: loss=108.7911, RMSE_E_per_atom=4612.2 meV, RMSE_F=935.5 meV / A
# 2023-07-26 16:48:29.240 INFO: Epoch 13: loss=110.5621, RMSE_E_per_atom=4533.0 meV, RMSE_F=948.8 meV / A
# 2023-07-26 16:48:31.840 INFO: Epoch 14: loss=108.0788, RMSE_E_per_atom=4490.2 meV, RMSE_F=937.6 meV / A
# 2023-07-26 16:48:33.379 INFO: Epoch 15: loss=108.2078, RMSE_E_per_atom=4445.3 meV, RMSE_F=940.5 meV / A
# 2023-07-26 16:48:34.943 INFO: Epoch 16: loss=103.7018, RMSE_E_per_atom=4402.4 meV, RMSE_F=918.3 meV / A
# 2023-07-26 16:48:37.062 INFO: Epoch 17: loss=105.4878, RMSE_E_per_atom=4353.9 meV, RMSE_F=930.2 meV / A
# 2023-07-26 16:48:39.375 INFO: Epoch 18: loss=96.5615, RMSE_E_per_atom=4302.9 meV, RMSE_F=883.4 meV / A
# 2023-07-26 16:48:42.150 INFO: Epoch 19: loss=92.6981, RMSE_E_per_atom=4230.9 meV, RMSE_F=864.9 meV / A
# 2023-07-26 16:48:44.839 INFO: Epoch 20: loss=91.0820, RMSE_E_per_atom=4132.8 meV, RMSE_F=860.2 meV / A
# 2023-07-26 16:48:46.967 INFO: Epoch 21: loss=82.9676, RMSE_E_per_atom=4043.9 meV, RMSE_F=816.2 meV / A
# 2023-07-26 16:48:49.566 INFO: Epoch 22: loss=80.0071, RMSE_E_per_atom=3982.9 meV, RMSE_F=800.9 meV / A
# 2023-07-26 16:48:52.331 INFO: Epoch 23: loss=75.0528, RMSE_E_per_atom=3921.8 meV, RMSE_F=772.5 meV / A
# 2023-07-26 16:48:55.055 INFO: Epoch 24: loss=70.3267, RMSE_E_per_atom=3833.8 meV, RMSE_F=745.8 meV / A
# 2023-07-26 16:48:57.560 INFO: Epoch 25: loss=65.7946, RMSE_E_per_atom=3757.7 meV, RMSE_F=718.9 meV / A
# 2023-07-26 16:48:59.360 INFO: Epoch 26: loss=60.2508, RMSE_E_per_atom=3668.9 meV, RMSE_F=684.0 meV / A
# 2023-07-26 16:49:01.633 INFO: Epoch 27: loss=59.7940, RMSE_E_per_atom=3537.5 meV, RMSE_F=687.6 meV / A
# 2023-07-26 16:49:03.936 INFO: Epoch 28: loss=60.5121, RMSE_E_per_atom=3410.7 meV, RMSE_F=699.1 meV / A
# 2023-07-26 16:49:05.885 INFO: Epoch 29: loss=58.5315, RMSE_E_per_atom=3300.9 meV, RMSE_F=690.2 meV / A
# 2023-07-26 16:49:05.906 INFO: Changing loss based on SWA
# 2023-07-26 16:49:07.948 INFO: Epoch 30: loss=10133.9189, RMSE_E_per_atom=3175.8 meV, RMSE_F=695.3 meV / A
# 2023-07-26 16:49:10.435 INFO: Epoch 31: loss=8897.4551, RMSE_E_per_atom=2972.8 meV, RMSE_F=772.2 meV / A
# 2023-07-26 16:49:13.187 INFO: Epoch 32: loss=7171.9717, RMSE_E_per_atom=2660.2 meV, RMSE_F=977.5 meV / A
# 2023-07-26 16:49:14.650 INFO: Epoch 33: loss=5166.8413, RMSE_E_per_atom=2232.6 meV, RMSE_F=1350.5 meV / A
# 2023-07-26 16:49:15.875 INFO: Epoch 34: loss=3623.2395, RMSE_E_per_atom=1826.5 meV, RMSE_F=1694.6 meV / A
# 2023-07-26 16:49:17.146 INFO: Epoch 35: loss=2719.9292, RMSE_E_per_atom=1543.3 meV, RMSE_F=1838.7 meV / A
# 2023-07-26 16:49:18.651 INFO: Epoch 36: loss=1967.6968, RMSE_E_per_atom=1264.7 meV, RMSE_F=1918.8 meV / A
# 2023-07-26 16:49:19.963 INFO: Epoch 37: loss=1425.4979, RMSE_E_per_atom=1031.5 meV, RMSE_F=1901.2 meV / A
# 2023-07-26 16:49:21.582 INFO: Epoch 38: loss=1044.4973, RMSE_E_per_atom=843.9 meV, RMSE_F=1822.9 meV / A
# 2023-07-26 16:49:24.172 INFO: Epoch 39: loss=763.4790, RMSE_E_per_atom=680.9 meV, RMSE_F=1731.4 meV / A
# 2023-07-26 16:49:26.444 INFO: Epoch 40: loss=570.5780, RMSE_E_per_atom=548.9 meV, RMSE_F=1640.9 meV / A
# 2023-07-26 16:49:29.477 INFO: Epoch 41: loss=437.7275, RMSE_E_per_atom=442.4 meV, RMSE_F=1555.6 meV / A
# 2023-07-26 16:49:31.773 INFO: Epoch 42: loss=350.1490, RMSE_E_per_atom=358.4 meV, RMSE_F=1488.9 meV / A
# 2023-07-26 16:49:33.884 INFO: Epoch 43: loss=288.3902, RMSE_E_per_atom=284.1 meV, RMSE_F=1441.2 meV / A
# 2023-07-26 16:49:36.065 INFO: Epoch 44: loss=248.5231, RMSE_E_per_atom=232.8 meV, RMSE_F=1394.0 meV / A
# 2023-07-26 16:49:38.148 INFO: Epoch 45: loss=220.5429, RMSE_E_per_atom=189.5 meV, RMSE_F=1358.8 meV / A
# 2023-07-26 16:49:40.650 INFO: Epoch 46: loss=201.0480, RMSE_E_per_atom=154.2 meV, RMSE_F=1331.4 meV / A
# 2023-07-26 16:49:43.772 INFO: Epoch 47: loss=185.8392, RMSE_E_per_atom=124.6 meV, RMSE_F=1305.1 meV / A
# 2023-07-26 16:49:46.138 INFO: Epoch 48: loss=175.1745, RMSE_E_per_atom=101.0 meV, RMSE_F=1284.4 meV / A
# 2023-07-26 16:49:48.947 INFO: Epoch 49: loss=166.5772, RMSE_E_per_atom=83.2 meV, RMSE_F=1263.5 meV / A
# 2023-07-26 16:49:48.962 INFO: Training complete
# 2023-07-26 16:49:48.965 INFO: Computing metrics for training, validation, and test sets
# 2023-07-26 16:49:48.967 INFO: Loading checkpoint: checkpoints/model_small2_run-567_epoch-29.pt
# 2023-07-26 16:49:48.986 INFO: Loaded model from epoch 29
# 2023-07-26 16:49:49.086 INFO: Evaluating train ...
# 2023-07-26 16:49:50.935 INFO: Evaluating valid ...
# 2023-07-26 16:49:51.069 INFO:
# +-------------+---------------------+------------------+-------------------+
# | config_type | RMSE E / meV / atom | RMSE F / meV / A | relative F RMSE % |
# +-------------+---------------------+------------------+-------------------+
# |    train    |        3357.8       |      443.3       |       17.52       |
# |    valid    |        3300.9       |      690.2       |       23.06       |
# +-------------+---------------------+------------------+-------------------+
# 2023-07-26 16:49:51.069 INFO: Saving model to checkpoints/model_small2_run-567.model
# 2023-07-26 16:49:51.150 INFO: Loading checkpoint: checkpoints/model_small2_run-567_epoch-49_swa.pt
# 2023-07-26 16:49:51.171 INFO: Loaded model from epoch 49
# 2023-07-26 16:49:51.296 INFO: Evaluating train ...
# 2023-07-26 16:49:52.612 INFO: Evaluating valid ...
# 2023-07-26 16:49:52.756 INFO:
# +-------------+---------------------+------------------+-------------------+
# | config_type | RMSE E / meV / atom | RMSE F / meV / A | relative F RMSE % |
# +-------------+---------------------+------------------+-------------------+
# |    train    |         98.5        |      627.5       |       24.80       |
# |    valid    |         83.2        |      1263.5      |       42.22       |
# +-------------+---------------------+------------------+-------------------+
# 2023-07-26 16:49:52.756 INFO: Saving model to checkpoints/model_small2_run-567_swa.model
# 2023-07-26 16:49:52.833 INFO: Done
# 2023-07-26 16:49:58.084 INFO: MACE version: 0.2.0
# 2023-07-26 16:49:58.085 INFO: Configuration: Namespace(name='model_small3', seed=731, log_dir='logs', model_dir='.', checkpoints_dir='checkpoints', results_dir='results', downloads_dir='downloads', device='cpu', default_dtype='float32', log_level='INFO', error_table='PerAtomRMSE', model='MACE', r_max=3.0, num_radial_basis=8, num_cutoff_basis=5, interaction='RealAgnosticResidualInteractionBlock', interaction_first='RealAgnosticResidualInteractionBlock', max_ell=2, correlation=2, num_interactions=2, MLP_irreps='16x0e', radial_MLP='[64, 64, 64]', hidden_irreps='16x0e', num_channels=None, max_L=None, gate='silu', scaling='rms_forces_scaling', avg_num_neighbors=1, compute_avg_num_neighbors=True, compute_stress=False, compute_forces=True, train_file='data/solvent_mace_small3_train.xyz', valid_file=None, valid_fraction=0.05, test_file=None, E0s='isolated', energy_key='energy', forces_key='forces', virials_key='virials', stress_key='stress', dipole_key='dipole', charges_key='charges', loss='weighted', forces_weight=100.0, swa_forces_weight=100.0, energy_weight=1.0, swa_energy_weight=1000.0, virials_weight=1.0, swa_virials_weight=10.0, stress_weight=1.0, swa_stress_weight=10.0, dipole_weight=1.0, swa_dipole_weight=1.0, config_type_weights='{"Default":1.0}', huber_delta=0.01, optimizer='adam', batch_size=5, valid_batch_size=5, lr=0.01, swa_lr=0.001, weight_decay=5e-07, amsgrad=True, scheduler='ReduceLROnPlateau', lr_factor=0.8, scheduler_patience=50, lr_scheduler_gamma=0.9993, swa=True, start_swa=30, ema=True, ema_decay=0.99, max_num_epochs=50, patience=2048, eval_interval=1, keep_checkpoints=False, restart_latest=False, save_cpu=False, clip_grad=10.0, wandb=False, wandb_project='', wandb_entity='', wandb_name='', wandb_log_hypers=['num_channels', 'max_L', 'correlation', 'lr', 'swa_lr', 'weight_decay', 'batch_size', 'max_num_epochs', 'start_swa', 'energy_weight', 'forces_weight'])
# 2023-07-26 16:49:58.085 INFO: Using CPU
# 2023-07-26 16:49:58.132 INFO: Using isolated atom energies from training file
# 2023-07-26 16:49:58.137 INFO: Loaded 50 training configurations from 'data/solvent_mace_small3_train.xyz'
# 2023-07-26 16:49:58.137 INFO: Using random 5.0% of training set for validation
# 2023-07-26 16:49:58.137 INFO: Total number of configurations: train=48, valid=2, tests=[]
# 2023-07-26 16:49:58.138 INFO: AtomicNumberTable: (1, 6, 8)
# 2023-07-26 16:49:58.138 INFO: Atomic energies: [-10.707211383396714, -48.847445262804705, -102.57117256025786]
# 2023-07-26 16:49:58.298 INFO: WeightedEnergyForcesLoss(energy_weight=1.000, forces_weight=100.000)
# 2023-07-26 16:49:58.332 INFO: Average number of neighbors: 7.129274368286133
# 2023-07-26 16:49:58.332 INFO: Selected the following outputs: {'energy': True, 'forces': True, 'virials': False, 'stress': False, 'dipoles': False}
# 2023-07-26 16:49:58.333 INFO: Building model
# 2023-07-26 16:49:58.333 INFO: Hidden irreps: 16x0e
# 2023-07-26 16:50:00.551 INFO: Using stochastic weight averaging (after 30 epochs) with energy weight : 1000.0, forces weight : 100.0 and learning rate : 0.001
# 2023-07-26 16:50:00.633 INFO: ScaleShiftMACE(
#   (node_embedding): LinearNodeEmbeddingBlock(
#     (linear): Linear(3x0e -> 16x0e | 48 weights)
#   )
#   (radial_embedding): RadialEmbeddingBlock(
#     (bessel_fn): BesselBasis(r_max=3.0, num_basis=8, trainable=False)
#     (cutoff_fn): PolynomialCutoff(p=5.0, r_max=3.0)
#   )
#   (spherical_harmonics): SphericalHarmonics()
#   (atomic_energies_fn): AtomicEnergiesBlock(energies=[-10.7072, -48.8474, -102.5712])
#   (interactions): ModuleList(
#     (0): RealAgnosticInteractionBlock(
#       (linear_up): Linear(16x0e -> 16x0e | 256 weights)
#       (conv_tp): TensorProduct(16x0e x 1x0e+1x1o+1x2e -> 16x0e+16x1o+16x2e | 48 paths | 48 weights)
#       (conv_tp_weights): FullyConnectedNet[8, 64, 64, 64, 48]
#       (linear): Linear(16x0e+16x1o+16x2e -> 16x0e+16x1o+16x2e | 768 weights)
#       (skip_tp): FullyConnectedTensorProduct(16x0e+16x1o+16x2e x 3x0e -> 16x0e+16x1o+16x2e | 2304 paths | 2304 weights)
#       (reshape): reshape_irreps()
#     )
#     (1): RealAgnosticResidualInteractionBlock(
#       (linear_up): Linear(16x0e -> 16x0e | 256 weights)
#       (conv_tp): TensorProduct(16x0e x 1x0e+1x1o+1x2e -> 16x0e+16x1o+16x2e | 48 paths | 48 weights)
#       (conv_tp_weights): FullyConnectedNet[8, 64, 64, 64, 48]
#       (linear): Linear(16x0e+16x1o+16x2e -> 16x0e+16x1o+16x2e | 768 weights)
#       (skip_tp): FullyConnectedTensorProduct(16x0e x 3x0e -> 16x0e | 768 paths | 768 weights)
#       (reshape): reshape_irreps()
#     )
#   )
#   (products): ModuleList(
#     (0): EquivariantProductBasisBlock(
#       (symmetric_contractions): SymmetricContraction(
#         (contractions): ModuleList(
#           (0): Contraction(
#             (contractions_weighting): ModuleList(
#               (0): GraphModule()
#             )
#             (contractions_features): ModuleList(
#               (0): GraphModule()
#             )
#             (weights): ParameterList(  (0): Parameter containing: [torch.FloatTensor of size 3x1x16])
#             (graph_opt_main): GraphModule()
#           )
#         )
#       )
#       (linear): Linear(16x0e -> 16x0e | 256 weights)
#     )
#     (1): EquivariantProductBasisBlock(
#       (symmetric_contractions): SymmetricContraction(
#         (contractions): ModuleList(
#           (0): Contraction(
#             (contractions_weighting): ModuleList(
#               (0): GraphModule()
#             )
#             (contractions_features): ModuleList(
#               (0): GraphModule()
#             )
#             (weights): ParameterList(  (0): Parameter containing: [torch.FloatTensor of size 3x1x16])
#             (graph_opt_main): GraphModule()
#           )
#         )
#       )
#       (linear): Linear(16x0e -> 16x0e | 256 weights)
#     )
#   )
#   (readouts): ModuleList(
#     (0): LinearReadoutBlock(
#       (linear): Linear(16x0e -> 1x0e | 16 weights)
#     )
#     (1): NonLinearReadoutBlock(
#       (linear_1): Linear(16x0e -> 16x0e | 256 weights)
#       (non_linearity): Activation [x] (16x0e -> 16x0e)
#       (linear_2): Linear(16x0e -> 1x0e | 16 weights)
#     )
#   )
#   (scale_shift): ScaleShiftBlock(scale=2.386815, shift=0.000000)
# )
# 2023-07-26 16:50:00.636 INFO: Number of parameters: 29904
# 2023-07-26 16:50:00.636 INFO: Optimizer: Adam (
# Parameter Group 0
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: embedding
#     swa_lr: 0.001
#     weight_decay: 0.0
#
# Parameter Group 1
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: interactions_decay
#     swa_lr: 0.001
#     weight_decay: 5e-07
#
# Parameter Group 2
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: interactions_no_decay
#     swa_lr: 0.001
#     weight_decay: 0.0
#
# Parameter Group 3
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: products
#     swa_lr: 0.001
#     weight_decay: 5e-07
#
# Parameter Group 4
#     amsgrad: True
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     name: readouts
#     swa_lr: 0.001
#     weight_decay: 0.0
# )
# 2023-07-26 16:50:00.636 INFO: Using gradient clipping with tolerance=10.000
# 2023-07-26 16:50:00.636 INFO: Started training
# 2023-07-26 16:50:08.554 INFO: Epoch 0: loss=953.5760, RMSE_E_per_atom=6265.1 meV, RMSE_F=3023.8 meV / A
# 2023-07-26 16:50:11.866 INFO: Epoch 1: loss=748.9333, RMSE_E_per_atom=5992.9 meV, RMSE_F=2670.2 meV / A
# 2023-07-26 16:50:14.091 INFO: Epoch 2: loss=504.1386, RMSE_E_per_atom=5919.8 meV, RMSE_F=2165.9 meV / A
# 2023-07-26 16:50:15.763 INFO: Epoch 3: loss=272.5421, RMSE_E_per_atom=5655.8 meV, RMSE_F=1551.0 meV / A
# 2023-07-26 16:50:17.453 INFO: Epoch 4: loss=216.8751, RMSE_E_per_atom=5666.7 meV, RMSE_F=1359.3 meV / A
# 2023-07-26 16:50:20.103 INFO: Epoch 5: loss=197.3763, RMSE_E_per_atom=5606.5 meV, RMSE_F=1288.2 meV / A
# 2023-07-26 16:50:22.670 INFO: Epoch 6: loss=199.5070, RMSE_E_per_atom=5561.3 meV, RMSE_F=1298.4 meV / A
# 2023-07-26 16:50:25.344 INFO: Epoch 7: loss=158.6119, RMSE_E_per_atom=5517.4 meV, RMSE_F=1132.1 meV / A
# 2023-07-26 16:50:27.572 INFO: Epoch 8: loss=132.7683, RMSE_E_per_atom=5432.2 meV, RMSE_F=1016.2 meV / A
# 2023-07-26 16:50:29.888 INFO: Epoch 9: loss=115.0123, RMSE_E_per_atom=5385.3 meV, RMSE_F=927.4 meV / A
# 2023-07-26 16:50:32.374 INFO: Epoch 10: loss=112.0807, RMSE_E_per_atom=5341.3 meV, RMSE_F=914.1 meV / A
# 2023-07-26 16:50:33.643 INFO: Epoch 11: loss=97.2049, RMSE_E_per_atom=5337.8 meV, RMSE_F=828.9 meV / A
# 2023-07-26 16:50:35.561 INFO: Epoch 12: loss=106.5219, RMSE_E_per_atom=5291.3 meV, RMSE_F=886.1 meV / A
# 2023-07-26 16:50:37.279 INFO: Epoch 13: loss=91.2065, RMSE_E_per_atom=5273.7 meV, RMSE_F=796.2 meV / A
# 2023-07-26 16:50:39.796 INFO: Epoch 14: loss=94.4737, RMSE_E_per_atom=5221.1 meV, RMSE_F=819.8 meV / A
# 2023-07-26 16:50:42.237 INFO: Epoch 15: loss=88.3456, RMSE_E_per_atom=5173.1 meV, RMSE_F=784.8 meV / A
# 2023-07-26 16:50:44.545 INFO: Epoch 16: loss=85.4989, RMSE_E_per_atom=5142.3 meV, RMSE_F=768.5 meV / A
# 2023-07-26 16:50:46.555 INFO: Epoch 17: loss=84.8140, RMSE_E_per_atom=5102.3 meV, RMSE_F=766.7 meV / A
# 2023-07-26 16:50:48.691 INFO: Epoch 18: loss=82.5490, RMSE_E_per_atom=5064.3 meV, RMSE_F=754.3 meV / A
# 2023-07-26 16:50:51.626 INFO: Epoch 19: loss=85.3787, RMSE_E_per_atom=5021.8 meV, RMSE_F=775.6 meV / A
# 2023-07-26 16:50:54.185 INFO: Epoch 20: loss=84.8697, RMSE_E_per_atom=4982.7 meV, RMSE_F=774.9 meV / A
# 2023-07-26 16:50:57.087 INFO: Epoch 21: loss=88.5196, RMSE_E_per_atom=4917.0 meV, RMSE_F=802.1 meV / A
# 2023-07-26 16:50:59.694 INFO: Epoch 22: loss=85.1883, RMSE_E_per_atom=4904.2 meV, RMSE_F=781.9 meV / A
# 2023-07-26 16:51:01.340 INFO: Epoch 23: loss=87.2325, RMSE_E_per_atom=4838.0 meV, RMSE_F=798.9 meV / A
# 2023-07-26 16:51:03.954 INFO: Epoch 24: loss=83.8723, RMSE_E_per_atom=4783.7 meV, RMSE_F=781.0 meV / A
# 2023-07-26 16:51:05.438 INFO: Epoch 25: loss=82.5221, RMSE_E_per_atom=4670.4 meV, RMSE_F=779.2 meV / A
# 2023-07-26 16:51:06.843 INFO: Epoch 26: loss=90.6209, RMSE_E_per_atom=4531.4 meV, RMSE_F=837.2 meV / A
# 2023-07-26 16:51:09.522 INFO: Epoch 27: loss=97.9280, RMSE_E_per_atom=4435.0 meV, RMSE_F=884.6 meV / A
# 2023-07-26 16:51:12.289 INFO: Epoch 28: loss=114.4756, RMSE_E_per_atom=4326.1 meV, RMSE_F=978.6 meV / A
# 2023-07-26 16:51:14.340 INFO: Epoch 29: loss=109.3141, RMSE_E_per_atom=4251.8 meV, RMSE_F=955.2 meV / A
# 2023-07-26 16:51:14.341 INFO: Changing loss based on SWA
# 2023-07-26 16:51:16.839 INFO: Epoch 30: loss=17427.6172, RMSE_E_per_atom=4163.7 meV, RMSE_F=952.9 meV / A
# 2023-07-26 16:51:19.073 INFO: Epoch 31: loss=16071.3994, RMSE_E_per_atom=3995.9 meV, RMSE_F=1020.8 meV / A
# 2023-07-26 16:51:21.222 INFO: Epoch 32: loss=14013.7656, RMSE_E_per_atom=3724.3 meV, RMSE_F=1197.0 meV / A
# 2023-07-26 16:51:22.772 INFO: Epoch 33: loss=11408.7598, RMSE_E_per_atom=3342.3 meV, RMSE_F=1541.4 meV / A
# 2023-07-26 16:51:25.291 INFO: Epoch 34: loss=8575.9160, RMSE_E_per_atom=2855.2 meV, RMSE_F=2058.6 meV / A
# 2023-07-26 16:51:27.683 INFO: Epoch 35: loss=6316.8555, RMSE_E_per_atom=2384.6 meV, RMSE_F=2511.0 meV / A
# 2023-07-26 16:51:30.384 INFO: Epoch 36: loss=4867.1152, RMSE_E_per_atom=2024.8 meV, RMSE_F=2770.3 meV / A
# 2023-07-26 16:51:32.752 INFO: Epoch 37: loss=3731.3625, RMSE_E_per_atom=1686.2 meV, RMSE_F=2980.2 meV / A
# 2023-07-26 16:51:34.189 INFO: Epoch 38: loss=2920.4753, RMSE_E_per_atom=1397.1 meV, RMSE_F=3112.4 meV / A
# 2023-07-26 16:51:37.386 INFO: Epoch 39: loss=2335.0781, RMSE_E_per_atom=1150.2 meV, RMSE_F=3181.5 meV / A
# 2023-07-26 16:51:40.163 INFO: Epoch 40: loss=1920.2302, RMSE_E_per_atom=947.2 meV, RMSE_F=3198.6 meV / A
# 2023-07-26 16:51:42.343 INFO: Epoch 41: loss=1610.8813, RMSE_E_per_atom=772.9 meV, RMSE_F=3183.5 meV / A
# 2023-07-26 16:51:44.448 INFO: Epoch 42: loss=1393.4445, RMSE_E_per_atom=637.9 meV, RMSE_F=3141.0 meV / A
# 2023-07-26 16:51:47.240 INFO: Epoch 43: loss=1228.5693, RMSE_E_per_atom=518.6 meV, RMSE_F=3097.8 meV / A
# 2023-07-26 16:51:50.066 INFO: Epoch 44: loss=1105.6238, RMSE_E_per_atom=426.9 meV, RMSE_F=3038.7 meV / A
# 2023-07-26 16:51:51.735 INFO: Epoch 45: loss=1007.4810, RMSE_E_per_atom=352.9 meV, RMSE_F=2971.5 meV / A
# 2023-07-26 16:51:54.262 INFO: Epoch 46: loss=929.4567, RMSE_E_per_atom=294.9 meV, RMSE_F=2902.6 meV / A
# 2023-07-26 16:51:57.079 INFO: Epoch 47: loss=858.2299, RMSE_E_per_atom=246.7 meV, RMSE_F=2823.8 meV / A
# 2023-07-26 16:51:59.179 INFO: Epoch 48: loss=795.4461, RMSE_E_per_atom=209.7 meV, RMSE_F=2741.3 meV / A
# 2023-07-26 16:52:01.564 INFO: Epoch 49: loss=740.1560, RMSE_E_per_atom=175.7 meV, RMSE_F=2663.3 meV / A
# 2023-07-26 16:52:01.582 INFO: Training complete
# 2023-07-26 16:52:01.583 INFO: Computing metrics for training, validation, and test sets
# 2023-07-26 16:52:01.586 INFO: Loading checkpoint: checkpoints/model_small3_run-731_epoch-25.pt
# 2023-07-26 16:52:01.606 INFO: Loaded model from epoch 25
# 2023-07-26 16:52:01.811 INFO: Evaluating train ...
# 2023-07-26 16:52:03.182 INFO: Evaluating valid ...
# 2023-07-26 16:52:03.449 INFO:
# +-------------+---------------------+------------------+-------------------+
# | config_type | RMSE E / meV / atom | RMSE F / meV / A | relative F RMSE % |
# +-------------+---------------------+------------------+-------------------+
# |    train    |        4231.4       |      455.4       |       19.43       |
# |    valid    |        4670.4       |      779.2       |       21.44       |
# +-------------+---------------------+------------------+-------------------+
# 2023-07-26 16:52:03.453 INFO: Saving model to checkpoints/model_small3_run-731.model
# 2023-07-26 16:52:03.546 INFO: Loading checkpoint: checkpoints/model_small3_run-731_epoch-49_swa.pt
# 2023-07-26 16:52:03.560 INFO: Loaded model from epoch 49
# 2023-07-26 16:52:03.595 INFO: Evaluating train ...
# 2023-07-26 16:52:04.752 INFO: Evaluating valid ...
# 2023-07-26 16:52:05.024 INFO:
# +-------------+---------------------+------------------+-------------------+
# | config_type | RMSE E / meV / atom | RMSE F / meV / A | relative F RMSE % |
# +-------------+---------------------+------------------+-------------------+
# |    train    |        140.6        |      701.1       |       29.91       |
# |    valid    |        175.7        |      2663.3      |       73.29       |
# +-------------+---------------------+------------------+-------------------+
# 2023-07-26 16:52:05.025 INFO: Saving model to checkpoints/model_small3_run-731_swa.model
# 2023-07-26 16:52:05.087 INFO: Done

# %% [markdown]
# Now we can run dynamics with a commitee of models and look at the variance in the energy prediction. Because XTB is cheap enough we can compare that variance with the true error. Do they correlate?

# %%
from aseMolec import extAtoms as ea
from ase import units
from ase.md.langevin import Langevin
from ase.md.velocitydistribution import Stationary, ZeroRotation, MaxwellBoltzmannDistribution
from ase.io import read, write

import random
import numpy as np
import time
import pylab as pl
from IPython import display

from xtb.ase.calculator import XTB
from mace.calculators import MACECalculator

model_paths = ['model_small1_swa.model','model_small2_swa.model', 'model_small3_swa.model']
xtb_calc = XTB(method="GFN2-xTB")
mace_calc = MACECalculator(model_paths=model_paths, device='cpu', default_dtype="float32")

init_conf = ea.sel_by_info_val(read('data/solvent_molecs.xyz',':'), 'Nmols', 1)[0].copy()
init_conf.set_calculator(mace_calc)

#initialize the temperature
random.seed(701)
MaxwellBoltzmannDistribution(init_conf, temperature_K=500)
Stationary(init_conf)
ZeroRotation(init_conf)

dyn = Langevin(init_conf, 1*units.fs, temperature_K=1200, friction=0.1)

# %matplotlib inline

time_fs = []
temperature = []
energies_1 = []
energies_2 = []
energies_3 = []
variances = []
xtb_energies = []
true_errors = []

! rm -rfv committee_md.xyz
fig, ax = pl.subplots(3, 1, figsize=(8,8), sharex='all', gridspec_kw={'hspace': 0, 'wspace': 0})


def write_frame():
        at = dyn.atoms.copy()
        at.calc = xtb_calc
        xtb_energy = at.get_potential_energy()

        dyn.atoms.write('committee_md.xyz', append=True)
        time_fs.append(dyn.get_time()/units.fs)
        temperature.append(dyn.atoms.get_temperature())
        energies_1.append(dyn.atoms.calc.results["energies"][0]/len(dyn.atoms))
        energies_2.append(dyn.atoms.calc.results["energies"][1]/len(dyn.atoms))
        energies_3.append(dyn.atoms.calc.results["energies"][2]/len(dyn.atoms))
        variances.append(dyn.atoms.calc.results["energy_var"]/len(dyn.atoms))
        xtb_energies.append(xtb_energy/len(dyn.atoms))
        true_errors.append(np.var([dyn.atoms.calc.results["energy"],xtb_energy])/len(dyn.atoms))

        # subplot the variance of the energy as a function of the steps and the temperature as two subplots
        ax[0].plot(np.array(time_fs), np.array(variances), color="y")
        ax[0].plot(np.array(time_fs), np.array(true_errors), color="black")
        ax[0].set_ylabel(r'$\Delta$ E (eV$^2$/atom)')
        ax[0].legend(['Estimated Error', 'True Error'], loc='lower left')

        # plot the temperature of the system as subplots
        ax[1].plot(np.array(time_fs), temperature, color="r", label='Temperature')
        ax[1].set_ylabel("T (K)")

        ax[2].plot(np.array(time_fs), energies_1, color="g")
        ax[2].plot(np.array(time_fs), energies_2, color="y")
        ax[2].plot(np.array(time_fs), energies_3, color="olive")
        ax[2].plot(np.array(time_fs), xtb_energies, color="black")
        ax[2].set_ylabel("E (eV/atom)")
        ax[2].set_xlabel('Time (fs)')
        ax[2].legend(['E mace1', 'E mace2', 'E mace3', 'E xtb'], loc='lower left')

        display.clear_output(wait=True)
        display.display(fig)
        time.sleep(0.01)

dyn.attach(write_frame, interval=10)
dyn.run(2000)
print("MD finished!")
# Out:
# MD finished!

# %% [markdown]
# As expected, the dynamics has failed. In this case our reference PES is xtb which is cheap to evaluate so we can easily check the error on the fly. In practice we will be trainking MLIPs on expensive reference methods, where computing the true error on the fly is impractical. Notice when the dynamics `explodes`, the `true error` divergese, but crucially the `estimated error` also diverges.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9485f16f-d74c-4d11-8957-82dc887c5ba6' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
